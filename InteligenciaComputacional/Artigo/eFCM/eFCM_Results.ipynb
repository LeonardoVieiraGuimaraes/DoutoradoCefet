# %% [markdown]
# # Resultados do Algoritmo eFCM
# ## Comparação de Acurácia (%) entre Algoritmos

# %% [markdown]
# | Dataset | eFMC | ALMMO | eT2Class | FLEXFIS | FBeM | IBeM | eGNN |
# |---------|------|-------|----------|---------|------|------|------|
# | Rotating Gaussians | 93.25 | 92.75 | NaN | 71.00 | 87.25 | 79.75 | 86.50 |
# | Iris Dataset | 94.66 | 66.67 | 94.66 | 90.00 | 90.00 | 60.00 | 90.66 |
# | Caesarian Section | 73.75 | 67.50 | 40.00 | 55.00 | 56.25 | 55.00 | 56.25 |
# | Somerville Happiness Survey | 62.92 | 59.46 | 32.13 | 50.50 | 54.86 | 54.86 | 47.91 |
# | Pima Indians Diabetes | 74.09 | 76.69 | 73.05 | 65.00 | 63.28 | 41.01 | 62.50 |
# | Website Phishing Dataset | 75.68 | 43.61 | 14.56 | 52.00 | 58.12 | 51.84 | 56.20 |
# | Glass Identification Dataset | 78.95 | 30.84 | 70.58 | 52.50 | 51.85 | 37.50 | 74.07 |
# | Wine Dataset | 97.19 | 66.85 | 73.59 | 63.00 | 87.07 | 60.11 | 88.76 |
# | Heart Disease | 80.18 | 82.17 | 16.49 | 54.50 | 62.17 | 54.61 | 64.47 |
# | Australian Credit Approval | 86.23 | 85.66 | 35.07 | 55.50 | 74.63 | 49.85 | 58.98 |
# | Mobile Price Classification | 68.00 | 46.80 | 16.00 | 25.50 | 35.85 | 25.00 | 24.50 |
# | Spambase Dataset | 83.61 | 88.92 | 44.44 | 61.00 | 39.40 | 39.39 | 60.58 |
# | **Average** | **80.71** | **67.32** | **46.42** | **57.96** | **63.39** | **50.74** | **64.28** |

# %% [markdown]
# ## Teste Estatístico p-value (eFMC vs Algoritmos)
# | Algoritmo Comparado | p-value |
# |---------------------|--------|
# | eFMC x ALMMo        | 0.029581 |
# | eFMC x eT2Class     | 0.000946 |
# | eFMC x FLEXFIS      | 0.001799 |
# | eFMC x FBeM         | 0.021191 |
# | eFMC x IBeM         | 1.317E-05 |
# | eFMC x eGNN         | 0.031615 |
