# %% [markdown]
# # Exclusão de Grupos e Regras e Atualização dos Parâmetros

# %% [markdown]
# ## Exclusão de Grupos e Regras
# $idade_t^i = t - A_i$
# Se $idade_t^i > mega$ e $n_t^i / t < 0.01$, excluir o grupo e a regra indexados por $i$, atualizar índices e número de grupos.

# %% [markdown]
# ## Atualização dos Parâmetros do Consequente
# **eFLS - Weighted Recursive Least Squares**
# $h_t^i = h_{t-1}^i + H_t^i x_{t-1} 	au_i (x_{t-1}) [y_{t-1}^i - ((x_{t-1})^T h_{t-1}^i)]$
# **eFMI - Multi-Innovations Recursive Weighted Least Squares**
# $h_t^i = h_{t-1}^i + L_t^i [Y_i(v_{r,t}) - 	heta_i(v_{r,t}) h_{t-1}^i]$
# **eFCE - Recursive Maximum Correntropy**
# $h_t^i = h_{t-1}^i + ta(x_t) H_t^i x_{t-1} 	au_i (x_{t-1}) [y_{t-1}^i - ((x_{t-1})^T h_{t-1}^i)]$
# **eFTLS - Recursive Weighted Total Least Squares**
# $h_t^i = rac{g_t^i u_t^i - (u_{t1} x_{t1} + ... + u_{tm} x_{tm})}{u_{t0}}$

# %% [markdown]
# ## Parâmetros dos Modelos Propostos
# Tabela com parâmetros para eFCE, eFLS, eFMI, eFTLS, eMG, eNFN, eOGS conforme experimentos (ver texto para detalhes).

# %% [markdown]
# ## Medidas de Desempenho
# $RMSE = qrt{rac{um_{t=1}^N (y_t - at{y}_t)^2}{N}}$
# $NDEI = rac{RMSE}{igma(at{y}_t)}$
# $RSS = um_{t=1}^N (y_t - at{y}_t)^2$
# $MGN = at{
# ho}_e qrt{rac{N-1}{1-at{
# ho}_e^2}}$

# %% [markdown]
# ## Previsão dos Preços dos Títulos da Global 40
# - 1665 amostras de preços diários de agosto/2000 a janeiro/2007
# - Objetivo: prever a direção dos preços
# - Modelo: $at{y}_t = f(y_{t-1}, y_{t-2})$

# %% [markdown]
# ### Resultados - Global 40
# | Modelos | RMSE | NDEI |
# |---------|------|------|
# | eFMI | 0.0113 | 0.0421 |
# | eFCE | 0.0113 | 0.0422 |
# | eMG | 0.0115 | 0.0428 |
# | eNFN | 0.0159 | 0.0603 |
# | eFLS | 0.0184 | 0.0683 |
# | eFTLS | 0.0187 | 0.0694 |
# | eOGS | 0.6341 | 2.3598 |

# %% [markdown]
# ## Previsão de Aluguel de Bicicletas
# - Capital Bike Sharing: 731 amostras em 2 anos
# - Objetivo: prever número de bicicletas alugadas
# - Modelo: $at{y}_t = f(x_{t1}, x_{t2}, ..., x_{t8}, x_{t9})$

# %% [markdown]
# ### Resultados - Bike Sharing
# | Modelos | RMSE | NDEI |
# |---------|------|------|
# | eFMI | 0.0953 | 0.4275 |
# | eNFN | 0.0966 | 0.4334 |
# | eFTLS | 0.1068 | 0.4794 |
# | eMG | 0.1096 | 0.4916 |
# | eFCE | 0.1284 | 0.5761 |
# | eOGS | 0.1376 | 0.5936 |
# | eFLS | 0.1583 | 0.7094 |

# %% [markdown]
# ## Trabalhos Futuros
# - Abordar técnicas de seleção automática de parâmetros dos modelos propostos;
# - Realizar análise de complexidade e investigar mecanismos;
# - Avaliar o uso de novos algoritmos para ajuste dos parâmetros do consequente;
# - Generalizar os modelos para problemas com múltiplas saídas e tarefas de classificação.
