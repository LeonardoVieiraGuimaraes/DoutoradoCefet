# %% [markdown]
# # Índice de Alerta e Criação/Atualização de Grupos e Regras

# %% [markdown]
# ## Índice de Alerta
# $a_t^i = p(V_t < z)$, com $a_t^i n [0, 1]$.

# %% [markdown]
# ## Criação dos Grupos e Regras
# - Criar um novo grupo se $amma_t^i < amma_{max}$, $orall i = 1, ..., c_t$ e $a_t^{i^*} > amma_a$ para $i^* = ax_i (amma_t^i)$.
# - Atualizar o número de grupos: $c_t = c_t + 1$;
# - Criar o grupo $c_t$;
# - Inicializar o número de amostras: $n_{tc}^t = 1$;
# - Inicializar o centro: $u_{tc}^t = x_t$;
# - Inicializar a matriz: $P_{tc}^t = P_{init}$;
# - Inicializar os parâmetros do consequente: $h_{tc}^t = rac{um_{i=1}^{c_t} h_t^i amma_t^i}{um_{i=1}^{c_t} amma_t^i}$;
# - Criar regra fuzzy $c_t$;
# - Atualizar os índices dos grupos e regras.

# %% [markdown]
# ## Atualização dos Grupos e Regras
# - Atualizar o grupo mais compatível se $amma_t^i > amma_{max}$, $orall i = 1, ..., c_t$ e/ou $a_t^{i^*} < amma_a$ para $i^* = ax_i (amma_t^i)$.
# - Atualizar o centro do grupo $u_{t+1}^{i^*} = u_t^{i^*} + S_t^{i^*}(x_t - u_t^{i^*})$, onde $S_t^{i^*} = ambda (amma_t^{i^*})^{1 - a_t^{i^*}}$;
# - Atualizar a matriz de dispersão: $P_t^{i^*}$;
# - $X_{t+1}^{i^*} = (1 - S_t^{i^*})(X_t^{i^*} - S_t^{i^*}(x_t - u_t^{i^*})(x_t - u_t^{i^*})^T)$.

# %% [markdown]
# ## Mesclagem de Grupos e Regras
# - Se $||u_t^{i^*} - u_t^i|| eq
# ho$ com $i = 1, ..., c_t$, $i
# eq i^*$ e $
# ho n [0, 1]$.
# - Calcular o centro: $u_t^{i^* up i} = u_t^{i^*} - rac{n_t^i}{n_t^{i^*} + n_t^i}(u_t^{i^*} - u_t^i)$;
# - Calcular a dispersão da matriz: $X_t^{i^* up i} = rac{P_t^{i^*} + P_t^i}{2}$;
# - Calcular os parâmetros do consequente: $h_t^{i^* up i} = rac{h_t^{i^*} amma_t^{i^*} + h_t^i amma_t^i}{amma_t^{i^*} + amma_t^i}$;
# - Calcular o número de amostras: $n_t^{i^* up i} = n_t^i + n_t^{i^*}$;
# - Atualizar o número de grupos: $c_t = c_t - 1$;
# - Atualizar os índices dos grupos e regras.
