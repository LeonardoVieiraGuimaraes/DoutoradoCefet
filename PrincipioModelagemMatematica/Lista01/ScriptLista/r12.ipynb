# %% [markdown]
# # R12 - Formulação orbital sem G
#
# ## Objetivo
# Mostrar por que a formulação da revolução de dois corpos sem a constante gravitacional $G$ fica dimensionalmente incompleta.

# %% [markdown]
# ## Fundamentação Teórica
# Sem incluir $G$ no conjunto de variáveis, não há parâmetro com dimensão capaz de acoplar corretamente escalas de massa, comprimento e tempo para fechar a lei orbital.
#
# Em termos de Buckingham Pi, faltam variáveis fisicamente relevantes para formar grupos que representem a dinâmica gravitacional completa.

# %%
import pandas as pd

# %%
# Ilustracao de contagem para dois cenarios
df = pd.DataFrame({
    'Cenario': ['Sem G', 'Com G'],
    'n (variaveis)': [4, 5],
    'm (dimensoes)': [3, 3]
})
df['p = n-m'] = df['n (variaveis)'] - df['m (dimensoes)']
df

# %%
print('Conclusao: sem G, a estrutura fisica orbital fica subespecificada para deduzir uma lei completa de periodo orbital.')

# %% [markdown]
# ## Conclusão
# A ausência de $G$ impede a construção adequada da relação orbital completa; por isso, a formulação sem $G$ não reproduz corretamente a dependência temporal da órbita.
