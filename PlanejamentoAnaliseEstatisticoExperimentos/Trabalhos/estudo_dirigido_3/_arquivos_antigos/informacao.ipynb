# %%
import os
import pandas as pd

def info_csv(pasta=r'D:\OneDrive\Pessoais\Doutorado\Cefet\data'):
    """Mostra informações básicas dos arquivos CSV."""
    
    if not os.path.exists(pasta):
        print(f"❌ Pasta '{pasta}' não encontrada!")
        return
    
    arquivos = [f for f in os.listdir(pasta) if f.endswith('.csv')]
    
    if not arquivos:
        print("❌ Nenhum arquivo CSV encontrado!")
        return
    
    print("📊 INFORMAÇÕES DOS ARQUIVOS CSV")
    print("=" * 40)
    
    for arquivo in arquivos:
        caminho = os.path.join(pasta, arquivo)
        
        try:
            # Tamanho
            tamanho_mb = os.path.getsize(caminho) / (1024*1024)
            
            # Dados
            df = pd.read_csv(caminho)
            
            print(f"\n📄 {arquivo}")
            print(f"   Tamanho: {tamanho_mb:.2f} MB")
            print(f"   Linhas: {df.shape[0]}")
            print(f"   Colunas: {df.shape[1]}")
            print(f"   Variáveis: {list(df.columns)}")
            
        except Exception as e:
            print(f"\n❌ {arquivo}: Erro - {e}")

# Executar
info_csv()
# Out:
# 📊 INFORMAÇÕES DOS ARQUIVOS CSV
# ========================================
#
# 📄 bd_gta_dentro_mg202505091607.csv
#    Tamanho: 950.40 MB
#    Linhas: 8298490
#    Colunas: 1
#    Variáveis: ['nr_gta;"nr_serie";"id_gta";"dt_emissao_gta";"cod_produtor_origem";"cod_produtor_destino";"id_tipo_finalidade_gta";"ds_meio_transporte";"cod_municipio_origem";"nome_municipio_origem";"estado_origem";"cod_municipio_destino";"nome_municipio_destino";"estado_destino";"qtd"']
#
# 📄 bd_gta_dentro_mg_faixa_etaria202505091602.csv
#    Tamanho: 652.78 MB
#    Linhas: 11838896
#    Colunas: 1
#    Variáveis: ['id_gta;"dt_emissao_gta";"ds_faixa_etaria";"tp_sexo";"qt_animais"']
#
# 📄 bd_gta_oe202505091618.csv
#    Tamanho: 6.46 MB
#    Linhas: 64677
#    Colunas: 1
#    Variáveis: ['nr_gta;"nr_serie";"id_gta_origem_outro_estado";"dt_emissao_gta";"cod_produtor_origem";"cod_produtor_destino";"id_tipo_finalidade_gta";"municipio_origem";"cod_municipio_origem";"estado_origem";"municipio_destino";"cod_municipio_destino";"estado_destino";"qtd"']
#
# 📄 bd_gta_oe_faixa_etaria202505091630.csv
#    Tamanho: 4.55 MB
#    Linhas: 87560
#    Colunas: 1
#    Variáveis: ['id_gta_origem_outro_estado;"dt_emissao_gta";"ds_faixa_etaria";"tp_sexo";"qt_animais"']
#
# 📄 gtas_com_distancias.csv
#    Tamanho: 1156.59 MB
#    Linhas: 8363167
#    Colunas: 1
#    Variáveis: ['nr_gta;nr_serie;id_gta;dt_emissao_gta;cod_produtor_origem;cod_produtor_destino;id_tipo_finalidade_gta;ds_meio_transporte;cod_municipio_origem;nome_municipio_origem;estado_origem;cod_municipio_destino;nome_municipio_destino;estado_destino;qtd;Acima de 36 meses;De 0 até 12 meses;De 13 até 24 meses;De 25 até 36 meses;distancia_km;duracao_min']
#
# 📄 matriz_distancias.csv
#    Tamanho: 370.34 MB
#    Linhas: 4751210
#    Colunas: 1
#    Variáveis: ['municipio_origem;municipio_destino;dist_rod_km;dist_rod_min;dist_ped_km;dist_ped_min']
#
# 📄 possiveis_fraudes.csv
#    Tamanho: 0.02 MB
#    Linhas: 311
#    Colunas: 1
#    Variáveis: ['id_gta;dt_emissao_gta;cod_produtor_origem;cod_produtor_destino;qtd;distancia_km;data_seconds']

# %% [markdown]
# # 📊 Informações CSV
#
# ## Função: `info_csv(pasta='data')`
#
# **O que faz:** Mostra informações básicas dos arquivos CSV
#
# **Informações mostradas:**
# - Tamanho do arquivo (MB)
# - Número de linhas
# - Número de colunas
# - Lista das variáveis
#
# **Como usar:**
# ```python
# info_csv()              # pasta 'data'
# info_csv('minha_pasta') # pasta específica
# ```
#
# ---
# **✅ Simples e direto ao ponto!**
