# %% [markdown]
# # Lista 01 – Exercícios de Algoritmos e Estruturas de Dados
#
# ---
#
# ## 1) Defina a complexidade e a ordem de complexidade das recorrências
#
# a)
# $$
# T(n) =
# \begin{cases}
# 0, & n = 1 \\
# T(n-1) + n - 1, & n > 1
# \end{cases}
# $$
#
# b)
# $$
# T(n) =
# \begin{cases}
# 0, & n = 1 \\
# T(n/2) + 1, & n > 1
# \end{cases}
# $$
#
# c)
# $$
# T(n) =
# \begin{cases}
# 0, & n = 1 \\
# 2T(n/2) + n - 1, & n > 1
# \end{cases}
# $$
#
# ---
#
# ## 2) Suponha algoritmos A e B com funções de complexidade de tempo
#
# - $a(n) = n^2 - n + 549$
# - $b(n) = 49n + 49$
#
# Determine para quais valores de $n \in \mathbb{N}$ o algoritmo A é mais rápido que B.
#
# ---
#
# ## 3) Considere o algoritmo abaixo:
#
# ```pseudo
# Pesquisa(n);
# if n <= 1
#     então "inspecione elemento" e termine
# senão
#     para cada um dos n elementos "inspecione elemento";
#     {
#         - de alguma forma isto permite descartar 1/3 dos elementos e fazer uma chamada recursiva no resto -
#     }
#     Pesquisa(2n/3);
# ```
#
# a) Escreva a equação de recorrência correspondente.
#
# b) Resolva a equação de recorrência.
#
# ---
#
# ## 4) Dê um exemplo que ilustre a não-estabilidade do método de ordenação Quicksort.
#
# ---
#
# ## 5) Em um heap de prioridade máxima, onde o menor elemento poderia ser encontrado?
#
# ---
#
# ## 6) Mostre o heap de prioridade máxima resultante do vetor abaixo.
#
# 4, 1, 3, 2, 16, 9, 10, 14, 8, 7
#
# ---
#
# ## 7) Considere a sequência de caracteres
#
# E S T R U T U R A D E D A D O S
#
# Mostre as etapas para a ordenação utilizando os métodos de Seleção, Inserção, Shellsort, Quicksort e Heapsort.
